# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# =========================
# Configuration
# =========================

CSV_PATH = Path("esrgan_training_log.csv")
SMOOTH_WINDOW = 25      # set to 1 to disable smoothing
FIGSIZE = (6.5, 4.0)

# =========================
# Utilities
# =========================

def smooth(series, window):
    if window <= 1:
        return series
    return series.rolling(window, center=True).mean()

# =========================
# Load data
# =========================

df = pd.read_csv(CSV_PATH)
epochs = df["epoch"]

# %%
# =========================
# Loss
# =========================

plt.figure(figsize=FIGSIZE)
plt.plot(epochs, smooth(df["train_g_loss"], SMOOTH_WINDOW), label="Train")
plt.plot(epochs, smooth(df["valid_g_loss"], SMOOTH_WINDOW), label="Validation")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("ESRGAN (GAN Training) Training and Validation Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# =========================
# PSNR
# =========================

plt.figure(figsize=FIGSIZE)
plt.plot(epochs, smooth(df["train_psnr"], SMOOTH_WINDOW), label="Train")
plt.plot(epochs, smooth(df["valid_psnr"], SMOOTH_WINDOW), label="Validation")
plt.xlabel("Epoch")
plt.ylabel("PSNR [dB]")
plt.title("ESRGAN (GAN Training) Training and Validation PSNR")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# =========================
# SSIM
# =========================

plt.figure(figsize=FIGSIZE)
plt.plot(epochs, smooth(df["train_ssim"], SMOOTH_WINDOW), label="Train")
plt.plot(epochs, smooth(df["valid_ssim"], SMOOTH_WINDOW), label="Validation")
plt.xlabel("Epoch")
plt.ylabel("SSIM")
plt.title("ESRGAN (GAN Training) Training and Validation SSIM")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# =========================
# LPIPS (validation only)
# =========================

plt.figure(figsize=FIGSIZE)
plt.plot(epochs, smooth(df["valid_lpips"], SMOOTH_WINDOW))
plt.xlabel("Epoch")
plt.ylabel("LPIPS")
plt.title("ESRGAN (GAN Training) Validation LPIPS")
plt.grid(True, alpha=0.3)
plt.show()
